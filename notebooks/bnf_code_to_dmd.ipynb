# %% [markdown]
# # Mapping BNF codes to dm+d

# %% [markdown]
# We have had a request from NHS England:
#
# >Our initial need is to have a reference file that can be used to map data in BNF code form (from NHS BSA) to drug information in dm+d (SNOMED) form (at VMP/AMP level but also with VTM information).
#
# We hold this information in the BQ database, and should be able to create a query to deliver this need.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
from matplotlib.dates import  DateFormatter
# %matplotlib inline
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps
import datetime

# %% [markdown]
# ## Create data from BigQuery

# %%
sql = """
  SELECT
  "vmp" AS type, # create type column, shows whether VMP or AMP
  vmp.id AS id, # VMP code
  vmp.nm AS nm, # VMP name
  vmp.vtm AS vtm, # VTM code
  vtm.nm AS vtm_nm, # VTM name
  bnf_code, # BNF code
  vpidprev AS vmp_previous, # Previous VMP code
  vpiddt AS vmp_previous_date # Date that previous VMP code changed
FROM
  ebmdatalab.dmd.vmp_full AS vmp
LEFT OUTER JOIN
  dmd.vtm AS vtm
ON
  vmp.vtm = vtm.id

UNION ALL # join VMP and AMP tables together to form single table
SELECT
  "amp" AS type,
  amp.id,
  amp.descr,
  vmp.vtm AS vtm,
  vtm.nm AS vtm_nm,
  amp.bnf_code AS bnf_code,
  NULL AS amp_previous,
  NULL AS amp_previous_date
FROM
  ebmdatalab.dmd.amp_full AS amp
INNER JOIN
  dmd.vmp AS vmp # join VMP to AMP table to get VMP codes to obtain VTM information
ON
  amp.vmp = vmp.id
LEFT OUTER JOIN
  dmd.vtm AS vtm
ON
  vmp.vtm = vtm.id
  """

exportfile = os.path.join("..","data","dmd_df.csv")
dmd_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)

# %%
dmd_df.head()
# Out:
#   type         id                                                 nm  \
# 0  vmp    6259002                      Hydrogen peroxide 3% solution
# 1  vmp   68461003                                     Lubricant gels
# 2  vmp  134460003  Irbesartan 300mg / Hydrochlorothiazide 12.5mg ...
# 3  vmp  134461004  Irbesartan 150mg / Hydrochlorothiazide 12.5mg ...
# 4  vmp  134463001                           Telmisartan 20mg tablets
#
#            vtm                            vtm_nm         bnf_code  \
# 0   31231007.0                 Hydrogen peroxide  1311060I0AAABAB
# 1          NaN                               NaN              NaN
# 2  398914000.0  Irbesartan + Hydrochlorothiazide  0205052A0AAABAB
# 3  398914000.0  Irbesartan + Hydrochlorothiazide  0205052A0AAAAAA
# 4  129487008.0                       Telmisartan  0205052Q0AAACAC
#
#    vmp_previous vmp_previous_date
# 0  4.224911e+15        2005-08-15
# 1  3.485311e+15        2006-01-04
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN

# %% [markdown]
# As we can see from above we appear to have successfully imported all `VMPs` and `AMPs`.  However, there are some products which either do not have a `VTM` or `bnf_code`.  We will explore this further below.

# %% [markdown]
# #### Check data with 12 months of primary care prescribing data

# %% [markdown]
# Importing prescribing data from BigQuery to check the impact of "missing" data

# %%
sql = """
SELECT
  bnf_code,
  bnf_name,
  SUM(items) AS items
FROM
  ebmdatalab.hscic.normalised_prescribing AS rx
WHERE
  month BETWEEN '2021-08-01'
  AND '2022-07-01'
GROUP BY
  bnf_name,
  bnf_code
  """

exportfile = os.path.join("..","data","rx_df.csv")
rx_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=TqQ4ZdHcluER8Hj6XqZcRU6rfoiI6Q&prompt=consent&access_type=offline
# Enter the authorization code:  4/1ARtbsJrjCR_Ou21T-ppSLpaAJVaDe4pSMPNqqLdoUztkLpgBRXASeeJm-dg
# Downloading: 100%|██████████| 27595/27595 [00:01<00:00, 19592.23rows/s]

# %%
rx_df.head()
# Out:
#           bnf_code                                           bnf_name    items
# 0  0906040G0BRABBW                Calcichew D3 Forte chewable tablets   840864
# 1  0906040G0AABYBY  Colecalciferol 400unit / Calcium carbonate 1.5...  1571449
# 2      21010900607  BD Viva hypodermic insulin needles for pre-fil...   446581
# 3  0407020Q0AAABAB  Morphine sulfate 10mg/1ml solution for injecti...   215700
# 4      21220000215                                          Zerocream   373162

# %% [markdown]
# We can now merge the two dataframes on BNF code

# %%
test_df = pd.merge(dmd_df, rx_df, left_on='bnf_code', right_on='bnf_code', how='right')

# %%
test_df.head()
# Out:
#   type            id                                                 nm  \
# 0  vmp  6.259002e+06                      Hydrogen peroxide 3% solution
# 1  amp  4.221611e+15  Hydrogen peroxide 3% solution (A A H Pharmaceu...
# 2  amp  4.222111e+15  Hydrogen peroxide 3% solution (Thornton & Ross...
# 3  amp  4.222611e+15  Hydrogen peroxide 3% solution (Alliance Health...
# 4  vmp  1.344600e+08  Irbesartan 300mg / Hydrochlorothiazide 12.5mg ...
#
#            vtm                            vtm_nm         bnf_code  \
# 0   31231007.0                 Hydrogen peroxide  1311060I0AAABAB
# 1   31231007.0                 Hydrogen peroxide  1311060I0AAABAB
# 2   31231007.0                 Hydrogen peroxide  1311060I0AAABAB
# 3   31231007.0                 Hydrogen peroxide  1311060I0AAABAB
# 4  398914000.0  Irbesartan + Hydrochlorothiazide  0205052A0AAABAB
#
#    vmp_previous vmp_previous_date  \
# 0  4.224911e+15        2005-08-15
# 1           NaN               NaN
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN
#
#                                             bnf_name  items
# 0                      Hydrogen peroxide 3% solution    263
# 1                      Hydrogen peroxide 3% solution    263
# 2                      Hydrogen peroxide 3% solution    263
# 3                      Hydrogen peroxide 3% solution    263
# 4  Irbesartan 300mg / Hydrochlorothiazide 12.5mg ...  19101

# %% [markdown]
# We can now check by seeing which items prescribed which don't have a corresponding `dm+d` code

# %%
test_df_no_dmd = test_df[test_df['id'].isnull()].sort_values(by='items', ascending=False) # filter only prescribing which has a null VMP or AMP
test_df_no_dmd.head()
# Out:
#        type  id   nm  vtm vtm_nm         bnf_code  vmp_previous  \
# 108089  NaN NaN  NaN  NaN    NaN  190201000AABLBL           NaN
# 108090  NaN NaN  NaN  NaN    NaN  190201000AABNBN           NaN
# 108088  NaN NaN  NaN  NaN    NaN  0904010H0BDACAA           NaN
# 108092  NaN NaN  NaN  NaN    NaN  130201000BBAHAV           NaN
# 108091  NaN NaN  NaN  NaN    NaN  0904010H0BYAMAA           NaN
#
#        vmp_previous_date                                      bnf_name   items
# 108089               NaN            Exception Handler Unspecified Item  122793
# 108090               NaN  Exception Handler Discount Not Deducted Item   17962
# 108088               NaN                Juvela gluten free bread rolls    6623
# 108092               NaN                               Ultrabase cream    3912
# 108091               NaN     Barkat gluten free wholemeal bread sliced     285

# %% [markdown]
# We can see from the above there are very few items apart from "unspecified item", which by definition cannot have a BNF code.

# %% [markdown]
# The other part of the request was to link `VTM` codes.  We can also check which drugs do not link to a `VTM`.

# %%
test_vtm_no_dmd  = test_df[test_df['vtm'].isnull()].sort_values(by='items', ascending=False)

# %%
test_vtm_no_dmd.head(30)
# Out:
#        type            id                                                 nm  \
# 64859   amp  1.742061e+16  Laxido Orange oral powder sachets sugar free (...
# 17166   amp  2.877031e+16  Macrogol compound oral powder sachets sugar fr...
# 17167   amp  3.355801e+16  Macrogol compound oral powder sachets sugar fr...
# 17165   amp  2.840711e+16  Macrogol compound oral powder sachets sugar fr...
# 17156   vmp  3.591211e+15  Macrogol compound oral powder sachets NPF suga...
# 17157   amp  1.550391e+16  Macrogol compound oral powder sachets sugar fr...
# 17158   amp  1.644631e+16  Macrogol compound oral powder sachets sugar fr...
# 17159   amp  1.928291e+16  Macrogol compound oral powder sachets sugar fr...
# 17160   amp  2.179041e+16  Macrogol compound oral powder sachets sugar fr...
# 17161   amp  2.239391e+16  Macrogol compound oral powder sachets sugar fr...
# 17162   amp  2.267331e+16  Macrogol compound oral powder sachets sugar fr...
# 17163   amp  2.437791e+16  Macrogol compound oral powder sachets sugar fr...
# 17164   amp  2.455401e+16  Macrogol compound oral powder sachets sugar fr...
# 17168   amp  3.903421e+16  Macrogol compound oral powder sachets sugar fr...
# 36744   amp  5.536110e+14        Dermol 500 lotion (Dermal Laboratories Ltd)
# 36669   amp  5.077110e+14                    Otomize ear spray (Teva UK Ltd)
# 106438  amp  3.909461e+16  FreeStyle Libre 2 Sensor (Abbott Laboratories ...
# 29730   amp  3.307111e+15  Vitamin B compound strong tablets (Alliance He...
# 29732   amp  1.416591e+16  Vitamin B compound strong tablets (Healthcare ...
# 29731   amp  9.798711e+15  Vitamin B compound strong tablets (Almus Pharm...
# 29728   amp  3.305411e+15  Vitamin B compound strong tablets (The Boots C...
# 29734   amp  2.275521e+16    Vitamin B compound strong tablets (Teva UK Ltd)
# 29735   amp  3.281171e+16  Vitamin B compound strong tablets (Genesis Pha...
# 29736   amp  3.557031e+16  Vitamin B compound strong tablets (NorthStar H...
# 29737   amp  3.727261e+16  Vitamin B compound strong tablets (Mawdsley-Br...
# 29738   amp  3.783161e+16  Vitamin B compound strong tablets (DE Pharmace...
# 29739   amp  3.990611e+16  Vitamin B compound strong tablets (Medihealth ...
# 29729   amp  3.306611e+15  Vitamin B compound strong tablets (Kent Pharma...
# 29733   amp  1.597891e+16  Vitamin B compound strong tablets (Zanza Speci...
# 29727   amp  3.303311e+15  Vitamin B compound strong tablets (Accord Heal...
#
#         vtm vtm_nm         bnf_code  vmp_previous vmp_previous_date  \
# 64859   NaN    NaN  0106040M0BCACAA           NaN               NaN
# 17166   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17167   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17165   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17156   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17157   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17158   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17159   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17160   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17161   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17162   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17163   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17164   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 17168   NaN    NaN  0106040M0AAAAAA           NaN               NaN
# 36744   NaN    NaN  130201000BBICBW           NaN               NaN
# 36669   NaN    NaN  120101050BCAAAB           NaN               NaN
# 106438  NaN    NaN      21480000101           NaN               NaN
# 29730   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29732   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29731   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29728   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29734   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29735   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29736   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29737   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29738   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29739   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29729   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29733   NaN    NaN  0906027G0AAABAB           NaN               NaN
# 29727   NaN    NaN  0906027G0AAABAB           NaN               NaN
#
#                                                  bnf_name    items
# 64859        Laxido Orange oral powder sachets sugar free  2703900
# 17166   Macrogol compound oral powder sachets NPF suga...  1696902
# 17167   Macrogol compound oral powder sachets NPF suga...  1696902
# 17165   Macrogol compound oral powder sachets NPF suga...  1696902
# 17156   Macrogol compound oral powder sachets NPF suga...  1696902
# 17157   Macrogol compound oral powder sachets NPF suga...  1696902
# 17158   Macrogol compound oral powder sachets NPF suga...  1696902
# 17159   Macrogol compound oral powder sachets NPF suga...  1696902
# 17160   Macrogol compound oral powder sachets NPF suga...  1696902
# 17161   Macrogol compound oral powder sachets NPF suga...  1696902
# 17162   Macrogol compound oral powder sachets NPF suga...  1696902
# 17163   Macrogol compound oral powder sachets NPF suga...  1696902
# 17164   Macrogol compound oral powder sachets NPF suga...  1696902
# 17168   Macrogol compound oral powder sachets NPF suga...  1696902
# 36744                                   Dermol 500 lotion  1678850
# 36669                                   Otomize ear spray  1306758
# 106438                           FreeStyle Libre 2 Sensor  1210030
# 29730                   Vitamin B compound strong tablets  1199121
# 29732                   Vitamin B compound strong tablets  1199121
# 29731                   Vitamin B compound strong tablets  1199121
# 29728                   Vitamin B compound strong tablets  1199121
# 29734                   Vitamin B compound strong tablets  1199121
# 29735                   Vitamin B compound strong tablets  1199121
# 29736                   Vitamin B compound strong tablets  1199121
# 29737                   Vitamin B compound strong tablets  1199121
# 29738                   Vitamin B compound strong tablets  1199121
# 29739                   Vitamin B compound strong tablets  1199121
# 29729                   Vitamin B compound strong tablets  1199121
# 29733                   Vitamin B compound strong tablets  1199121
# 29727                   Vitamin B compound strong tablets  1199121

# %%
#df.groupby(['Country', 'Item_Code'])[["Y1961", "Y1962", "Y1963"]].sum()

group_vtm_no_dmd = test_vtm_no_dmd.groupby(['bnf_name'])[['items']].mean().sort_values(by='items', ascending=False)

# %%
group_vtm_no_dmd.head(30)
# Out:
#                                                       items
# bnf_name
# Laxido Orange oral powder sachets sugar free        2703900
# Macrogol compound oral powder sachets NPF sugar...  1696902
# Dermol 500 lotion                                   1678850
# Otomize ear spray                                   1306758
# FreeStyle Libre 2 Sensor                            1210030
# Vitamin B compound strong tablets                   1199121
# GlucoRx Nexus testing strips                        1100323
# Epimax original cream                               1055408
# WaveSense JAZZ testing strips                        678138
# Medi Derma-S barrier cream                           624223
# Aveeno cream                                         617843
# AeroChamber Plus                                     602251
# Xailin Night eye ointment preservative free          586664
# TEE2 testing strips                                  560281
# Sharpsguard disposal unit 1 litre                    541441
# Sharpsafe disposal unit 1 litre                      539387
# AeroChamber Plus with mask                           538299
# GlucoRx lancets 0.31mm/30gauge                       525485
# FastClix lancets 0.3mm/30gauge                       486923
# Movicol Paediatric Plain oral powder 6.9g sachets    470942
# Proshield Plus skin protective                       465421
# Hylo Night eye ointment preservative free            464394
# BD Viva hypodermic insulin needles for pre-fill...   446581
# E45 cream                                            421563
# Dermol cream                                         418540
# GlucoMen areo Sensor testing strips                  414367
# Performa testing strips                              413787
# Cavilon Durable barrier cream                        406964
# Finetest Lite testing strips                         390703
# Fortisip Compact liquid (8 flavours)                 388180

# %% [markdown]
# The largest number of prescribing items with a `NULL` `VTM` are either a) where they are not drugs, but appliances or devices (such as Freestyle Libre), OR where the drug has more than 3 ingredients.  In this case (such as Laxido) no VTM is assigned to the formulation in the dm+d.  Therefore it appears that the table accurately reflects what the dm+d says.
