# %% [markdown]
# # Mapping BNF codes to dm+d

# %% [markdown]
# We have had a request from NHS England:
#
# >Our initial need is to have a reference file that can be used to map data in BNF code form (from NHS BSA) to drug information in dm+d (SNOMED) form (at VMP/AMP level but also with VTM information).
#
# We hold this information in the BQ database, and should be able to create a query to deliver this need.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
from matplotlib.dates import  DateFormatter
# %matplotlib inline
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps
import datetime
import openpyxl

# %% [markdown]
# ## Create data from BigQuery

# %%
sql = """
  SELECT
  "vmp" AS type, # create type column, shows whether VMP or AMP
  vmp.id AS id, # VMP code
  vmp.nm AS nm, # VMP name
  vmp.vtm AS vtm, # VTM code
  vtm.nm AS vtm_nm, # VTM name
  bnf_code, # BNF code
  vpidprev AS vmp_previous, # Previous VMP code
  vpiddt AS vmp_previous_date # Date that previous VMP code changed
FROM
  ebmdatalab.dmd.vmp_full AS vmp
LEFT OUTER JOIN
  dmd.vtm AS vtm
ON
  vmp.vtm = vtm.id

UNION ALL # join VMP and AMP tables together to form single table
SELECT
  "amp" AS type,
  amp.id,
  amp.descr,
  vmp.vtm AS vtm,
  vtm.nm AS vtm_nm,
  amp.bnf_code AS bnf_code,
  NULL AS amp_previous,
  NULL AS amp_previous_date
FROM
  ebmdatalab.dmd.amp_full AS amp
INNER JOIN
  dmd.vmp AS vmp # join VMP to AMP table to get VMP codes to obtain VTM information
ON
  amp.vmp = vmp.id
LEFT OUTER JOIN
  dmd.vtm AS vtm 
ON
  vmp.vtm = vtm.id 
  """

exportfile = os.path.join("..","data","bnf_to_dmd.csv")
dmd_df = bq.cached_read(sql, csv_path=exportfile, use_cache=False)
# Out:
# Downloading: 100%|██████████| 175923/175923 [00:12<00:00, 14008.03rows/s]

# %%
dmd_df.head()
# Out:
#   type         id                                                 nm  \
# 0  vmp   68461003                                     Lubricant gels
# 1  vmp  134619001  Doxorubicin (liposomal) 50mg/25ml solution for...
# 2  vmp  134754002            Carmellose 1% eye drops 0.4ml unit dose
# 3  vmp  318076002  Spironolactone 5mg/5ml oral suspension sugar free
# 4  vmp  318077006  Spironolactone 10mg/5ml oral suspension sugar ...
#
#            vtm                   vtm_nm bnf_code vmp_previous  \
# 0          NaN                     None     None  3.48531e+15
# 1  773365000.0  Doxorubicin (liposomal)     None          NaN
# 2  775072005.0               Carmellose     None          NaN
# 3  777603002.0           Spironolactone     None          NaN
# 4  777603002.0           Spironolactone     None          NaN
#
#   vmp_previous_date
# 0        2006-01-04
# 1               NaT
# 2               NaT
# 3               NaT
# 4               NaT

# %% [markdown]
# As we can see from above we appear to have successfully imported all `VMPs` and `AMPs`.  However, there are some products which either do not have a `VTM` or `bnf_code`.  We will explore this further below.

# %% [markdown]
# #### Check data with 12 months of primary care prescribing data

# %% [markdown]
# Importing prescribing data from BigQuery to check the impact of "missing" data

# %%
sql = """
SELECT
  bnf_code,
  bnf_name,
  SUM(items) AS items
FROM
  ebmdatalab.hscic.normalised_prescribing AS rx
WHERE
  month BETWEEN '2022-09-01'
  AND '2023-08-01'
GROUP BY
  bnf_name,
  bnf_code
  """

exportfile = os.path.join("..","data","rx_df.csv")
rx_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)

# %%
rx_df.head()
# Out:
#           bnf_code                                           bnf_name  \
# 0  1502010J0AABDBD  Lidocaine 50mg/5ml (1%) solution for injection...
# 1  0403010B0AAAGAG                         Amitriptyline 10mg tablets
# 2  0704020N0AAABAB                            Tolterodine 2mg tablets
# 3  0403040W0AAALAL         Venlafaxine 225mg modified-release tablets
# 4  0104020L0AAADAD                             Loperamide 2mg tablets
#
#       items
# 0     81521
# 1  10519629
# 2    432135
# 3    218058
# 4    118266

# %% [markdown]
# We can now merge the two dataframes on BNF code

# %%
test_df = pd.merge(dmd_df, rx_df, left_on='bnf_code', right_on='bnf_code', how='right')

# %%
test_df.head()
# Out:
#   type            id                                                 nm  \
# 0  vmp  7.217100e+13  Tetanus immunoglobulin human 250unit solution ...
# 1  amp  4.953011e+15  Tetanus immunoglobulin human 250unit solution ...
# 2  vmp  1.160810e+14                Imiquimod 3.75% cream 250mg sachets
# 3  vmp  1.162810e+14                    Lidocaine 5% medicated plasters
# 4  vmp  1.331410e+14                        Coal tar prepared 1% lotion
#
#            vtm                  vtm_nm         bnf_code vmp_previous  \
# 0  777724003.0  Tetanus immunoglobulin  1405020A0AAABAB  3.33769e+08
# 1  777724003.0  Tetanus immunoglobulin  1405020A0AAABAB          NaN
# 2  776315001.0               Imiquimod  1307000V0AAABAB  4.44988e+08
# 3  776528009.0               Lidocaine  1502010J0AAELEL  3.76491e+08
# 4  775333000.0                Coal tar  1305020C0AACXCX  3.32081e+08
#
#   vmp_previous_date                                        bnf_name   items
# 0        2022-01-12  Tetanus immunoglobulin human 250unit inj vials      28
# 1               NaT  Tetanus immunoglobulin human 250unit inj vials      28
# 2        2022-07-29             Imiquimod 3.75% cream 250mg sachets     943
# 3        2022-07-29                 Lidocaine 5% medicated plasters  106695
# 4        2022-07-29         Coal tar solution 5% cutaneous emulsion    6625

# %% [markdown]
# We can now check by seeing which items prescribed which don't have a corresponding `dm+d` code

# %%
test_df_no_dmd = test_df[test_df['id'].isnull()].sort_values(by='items', ascending=False) # filter only prescribing which has a null VMP or AMP
test_df_no_dmd.head()
# Out:
#        type  id   nm  vtm vtm_nm         bnf_code vmp_previous  \
# 105653  NaN NaN  NaN  NaN    NaN  190201000AABLBL          NaN
# 105654  NaN NaN  NaN  NaN    NaN  190201000AABPBP          NaN
# 105657  NaN NaN  NaN  NaN    NaN  190201000AABNBN          NaN
# 105655  NaN NaN  NaN  NaN    NaN  0913261J0BCAAAB          NaN
# 105656  NaN NaN  NaN  NaN    NaN  090402000BDFHA0          NaN
#
#        vmp_previous_date                                        bnf_name  \
# 105653               NaT              Exception Handler Unspecified Item
# 105654               NaT  Exception Handler High Volume Unspecified Item
# 105657               NaT    Exception Handler Discount Not Deducted Item
# 105655               NaT                                  ProZero liquid
# 105656               NaT    Fresubin Energy tube feed liquid unflavoured
#
#          items
# 105653  314805
# 105654  184530
# 105657   20008
# 105655    4549
# 105656     205

# %% [markdown]
# We can see from the above there are very few items apart from "unspecified item", which by definition cannot have a BNF code.

# %% [markdown]
# The other part of the request was to link `VTM` codes.  We can also check which drugs do not link to a `VTM`.

# %%
test_vtm_no_dmd  = test_df[test_df['vtm'].isnull()].sort_values(by='items', ascending=False)

# %%
test_vtm_no_dmd.head(30)
# Out:
#        type            id                                                 nm  \
# 62524   amp  1.742061e+16  Laxido Orange oral powder sachets sugar free (...
# 102741  amp  3.909461e+16  FreeStyle Libre 2 Sensor (Abbott Laboratories ...
# 864     amp  3.355801e+16  Macrogol compound oral powder sachets sugar fr...
# 861     amp  2.455401e+16  Macrogol compound oral powder sachets sugar fr...
# 865     amp  3.903421e+16  Macrogol compound oral powder sachets sugar fr...
# 860     amp  2.437791e+16  Macrogol compound oral powder sachets sugar fr...
# 859     amp  2.267331e+16  Macrogol compound oral powder sachets sugar fr...
# 858     amp  2.239391e+16  Macrogol compound oral powder sachets sugar fr...
# 857     amp  2.179041e+16  Macrogol compound oral powder sachets sugar fr...
# 856     amp  1.928291e+16  Macrogol compound oral powder sachets sugar fr...
# 855     amp  1.644631e+16  Macrogol compound oral powder sachets sugar fr...
# 854     amp  1.550391e+16  Macrogol compound oral powder sachets sugar fr...
# 853     vmp  3.591211e+15  Macrogol compound oral powder sachets NPF suga...
# 862     amp  2.840711e+16  Macrogol compound oral powder sachets sugar fr...
# 863     amp  2.877031e+16  Macrogol compound oral powder sachets sugar fr...
# 34478   amp  5.536110e+14        Dermol 500 lotion (Dermal Laboratories Ltd)
# 34404   amp  5.077110e+14                    Otomize ear spray (Teva UK Ltd)
# 85929   amp  2.796701e+16          Epimax original cream (Aspire Pharma Ltd)
# 11137   amp  3.281171e+16  Vitamin B compound strong tablets (Genesis Pha...
# 11136   amp  2.275521e+16    Vitamin B compound strong tablets (Teva UK Ltd)
# 11135   amp  1.597891e+16  Vitamin B compound strong tablets (Zanza Speci...
# 11127   vmp  3.482051e+16                  Vitamin B compound strong tablets
# 11128   amp  2.918911e+15  Vitamin B compound strong tablets (A A H Pharm...
# 11130   amp  3.305411e+15  Vitamin B compound strong tablets (The Boots C...
# 11131   amp  3.306611e+15  Vitamin B compound strong tablets (Kent Pharma...
# 11132   amp  3.307111e+15  Vitamin B compound strong tablets (Alliance He...
# 11138   amp  3.557031e+16  Vitamin B compound strong tablets (NorthStar H...
# 11129   amp  3.303311e+15  Vitamin B compound strong tablets (Accord-UK Ltd)
# 11134   amp  1.416591e+16  Vitamin B compound strong tablets (Healthcare ...
# 11139   amp  3.727261e+16  Vitamin B compound strong tablets (Mawdsley-Br...
#
#         vtm vtm_nm         bnf_code vmp_previous vmp_previous_date  \
# 62524   NaN   None  0106040M0BCACAA          NaN               NaT
# 102741  NaN   None      21480000101         None               NaT
# 864     NaN   None  0106040M0AAAAAA         None               NaT
# 861     NaN   None  0106040M0AAAAAA         None               NaT
# 865     NaN   None  0106040M0AAAAAA         None               NaT
# 860     NaN   None  0106040M0AAAAAA         None               NaT
# 859     NaN   None  0106040M0AAAAAA         None               NaT
# 858     NaN   None  0106040M0AAAAAA         None               NaT
# 857     NaN   None  0106040M0AAAAAA         None               NaT
# 856     NaN   None  0106040M0AAAAAA         None               NaT
# 855     NaN   None  0106040M0AAAAAA          NaN               NaT
# 854     NaN   None  0106040M0AAAAAA          NaN               NaT
# 853     NaN   None  0106040M0AAAAAA          NaN               NaT
# 862     NaN   None  0106040M0AAAAAA         None               NaT
# 863     NaN   None  0106040M0AAAAAA         None               NaT
# 34478   NaN   None  130201000BBICBW          NaN               NaT
# 34404   NaN   None  120101050BCAAAB          NaN               NaT
# 85929   NaN   None      21220000241         None               NaT
# 11137   NaN   None  0906027G0AAABAB         None               NaT
# 11136   NaN   None  0906027G0AAABAB         None               NaT
# 11135   NaN   None  0906027G0AAABAB          NaN               NaT
# 11127   NaN   None  0906027G0AAABAB  3.29298e+08        2017-10-05
# 11128   NaN   None  0906027G0AAABAB          NaN               NaT
# 11130   NaN   None  0906027G0AAABAB          NaN               NaT
# 11131   NaN   None  0906027G0AAABAB          NaN               NaT
# 11132   NaN   None  0906027G0AAABAB          NaN               NaT
# 11138   NaN   None  0906027G0AAABAB         None               NaT
# 11129   NaN   None  0906027G0AAABAB          NaN               NaT
# 11134   NaN   None  0906027G0AAABAB          NaN               NaT
# 11139   NaN   None  0906027G0AAABAB         None               NaT
#
#                                                  bnf_name    items
# 62524        Laxido Orange oral powder sachets sugar free  2655605
# 102741                           FreeStyle Libre 2 Sensor  2150585
# 864     Macrogol compound oral powder sachets NPF suga...  1917581
# 861     Macrogol compound oral powder sachets NPF suga...  1917581
# 865     Macrogol compound oral powder sachets NPF suga...  1917581
# 860     Macrogol compound oral powder sachets NPF suga...  1917581
# 859     Macrogol compound oral powder sachets NPF suga...  1917581
# 858     Macrogol compound oral powder sachets NPF suga...  1917581
# 857     Macrogol compound oral powder sachets NPF suga...  1917581
# 856     Macrogol compound oral powder sachets NPF suga...  1917581
# 855     Macrogol compound oral powder sachets NPF suga...  1917581
# 854     Macrogol compound oral powder sachets NPF suga...  1917581
# 853     Macrogol compound oral powder sachets NPF suga...  1917581
# 862     Macrogol compound oral powder sachets NPF suga...  1917581
# 863     Macrogol compound oral powder sachets NPF suga...  1917581
# 34478                                   Dermol 500 lotion  1821608
# 34404                                   Otomize ear spray  1404453
# 85929                               Epimax original cream  1216588
# 11137                   Vitamin B compound strong tablets  1038779
# 11136                   Vitamin B compound strong tablets  1038779
# 11135                   Vitamin B compound strong tablets  1038779
# 11127                   Vitamin B compound strong tablets  1038779
# 11128                   Vitamin B compound strong tablets  1038779
# 11130                   Vitamin B compound strong tablets  1038779
# 11131                   Vitamin B compound strong tablets  1038779
# 11132                   Vitamin B compound strong tablets  1038779
# 11138                   Vitamin B compound strong tablets  1038779
# 11129                   Vitamin B compound strong tablets  1038779
# 11134                   Vitamin B compound strong tablets  1038779
# 11139                   Vitamin B compound strong tablets  1038779

# %%
group_vtm_no_dmd = test_vtm_no_dmd.groupby(['bnf_name'])[['items']].mean().sort_values(by='items', ascending=False)

# %%
group_vtm_no_dmd.head(30)
# Out:
#                                                         items
# bnf_name
# Laxido Orange oral powder sachets sugar free        2655605.0
# FreeStyle Libre 2 Sensor                            2150585.0
# Macrogol compound oral powder sachets NPF sugar...  1917581.0
# Dermol 500 lotion                                   1821608.0
# Otomize ear spray                                   1404453.0
# Epimax original cream                               1216588.0
# Vitamin B compound strong tablets                   1038779.0
# GlucoRx Nexus testing strips                        1020083.0
# Medi Derma-S barrier cream                           780871.0
# WaveSense JAZZ testing strips                        641966.0
# AeroChamber Plus                                     616982.0
# Aveeno cream                                         594467.0
# GlucoRx lancets 0.31mm/30gauge                       560800.0
# TEE2 testing strips                                  552581.0
# Sharpsafe disposal unit 1 litre                      538011.0
# Sharpsguard disposal unit 1 litre                    535991.0
# Hylo Night eye ointment preservative free            535073.0
# AeroChamber Plus with mask                           533485.0
# Evorel Sequi patches                                 515739.0
# Xailin Night eye ointment preservative free          506890.0
# BD Viva hypodermic insulin needles for pre-fill...   499086.0
# Movicol Paediatric Plain oral powder 6.9g sachets    461458.0
# FastClix lancets 0.3mm/30gauge                       458615.0
# Proshield Plus skin protective                       456828.0
# Forceval capsules                                    428496.0
# Dermol cream                                         416425.0
# Fortisip Compact liquid (8 flavours)                 402004.0
# Finetest Lite testing strips                         399933.0
# E45 cream                                            394031.0
# GlucoMen areo Sensor testing strips                  380857.0

# %% [markdown]
# The largest number of prescribing items with a `NULL` `VTM` are either a) where they are not drugs, but appliances or devices (such as Freestyle Libre), OR where the drug has more than 3 ingredients.  In this case (such as Laxido) no VTM is assigned to the formulation in the dm+d.  Therefore it appears that the table accurately reflects what the dm+d says.
