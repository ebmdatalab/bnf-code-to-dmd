# %% [markdown]
# # Mapping BNF codes to dm+d

# %% [markdown]
# We have had a request from NHS England:
#
# >Our initial need is to have a reference file that can be used to map data in BNF code form (from NHS BSA) to drug information in dm+d (SNOMED) form (at VMP/AMP level but also with VTM information).
#
# We hold this information in the BQ database, and should be able to create a query to deliver this need.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
from matplotlib.dates import  DateFormatter
# %matplotlib inline
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps
import datetime
import openpyxl

# %% [markdown]
# ## Create data from BigQuery

# %%
sql = """
  SELECT
  "vmp" AS type, # create type column, shows whether VMP or AMP
  vmp.id AS id, # VMP code
  vmp.nm AS nm, # VMP name
  vmp.vtm AS vtm, # VTM code
  vtm.nm AS vtm_nm, # VTM name
  bnf_code, # BNF code
  vpidprev AS vmp_previous, # Previous VMP code
  vpiddt AS vmp_previous_date # Date that previous VMP code changed
FROM
  ebmdatalab.dmd.vmp_full AS vmp
LEFT OUTER JOIN
  dmd.vtm AS vtm
ON
  vmp.vtm = vtm.id

UNION ALL # join VMP and AMP tables together to form single table
SELECT
  "amp" AS type,
  amp.id,
  amp.descr,
  vmp.vtm,
  vtm.nm AS vtm_nm,
  amp.bnf_code AS bnf_code,
  NULL AS amp_previous,
  NULL AS amp_previous_date
FROM
  ebmdatalab.dmd.amp_full AS amp
INNER JOIN
  dmd.vmp AS vmp # join VMP to AMP table to get VMP codes to obtain VTM information
ON
  amp.vmp = vmp.id
LEFT OUTER JOIN
  dmd.vtm AS vtm 
ON
  vmp.vtm = vtm.id 
  """
exportfile = os.path.join("..","data","dmd_df.csv")
dmd_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)
exportfile2 = os.path.join("..","data","bnf_to_dmd.csv")
dmd_df['id'] = dmd_df['id'].astype('Int64')  # ensure csv is integer
dmd_df['vtm'] = dmd_df['vtm'].astype('Int64') # ensure csv is integer
dmd_df['vmp_previous'] = dmd_df['vmp_previous'].astype('Int64') # ensure csv is integer
exportfile2 = os.path.join("..","data","bnf_to_dmd.csv")
dmd_df.to_csv(exportfile2) # export integer version
# Out:
# Downloading: 100%|██████████| 175923/175923 [00:14<00:00, 12161.68rows/s]

# %%
dmd_df.head()
# Out:
#   type         id                                                 nm  \
# 0  vmp   68461003                                     Lubricant gels
# 1  vmp  134619001  Doxorubicin (liposomal) 50mg/25ml solution for...
# 2  vmp  134754002            Carmellose 1% eye drops 0.4ml unit dose
# 3  vmp  318076002  Spironolactone 5mg/5ml oral suspension sugar free
# 4  vmp  318077006  Spironolactone 10mg/5ml oral suspension sugar ...
#
#          vtm                   vtm_nm bnf_code      vmp_previous  \
# 0       <NA>                     None     None  3485311000001105
# 1  773365000  Doxorubicin (liposomal)     None              <NA>
# 2  775072005               Carmellose     None              <NA>
# 3  777603002           Spironolactone     None              <NA>
# 4  777603002           Spironolactone     None              <NA>
#
#   vmp_previous_date
# 0        2006-01-04
# 1               NaT
# 2               NaT
# 3               NaT
# 4               NaT

# %% [markdown]
# As we can see from above we appear to have successfully imported all `VMPs` and `AMPs`.  However, there are some products which either do not have a `VTM` or `bnf_code`.  We will explore this further below.

# %% [markdown]
# #### Check data with 12 months of primary care prescribing data

# %% [markdown]
# Importing prescribing data from BigQuery to check the impact of "missing" data

# %%
sql = """
SELECT
  bnf_code,
  bnf_name,
  SUM(items) AS items
FROM
  ebmdatalab.hscic.normalised_prescribing AS rx
WHERE
  month BETWEEN '2022-09-01'
  AND '2023-08-01'
GROUP BY
  bnf_name,
  bnf_code
  """

exportfile = os.path.join("..","data","rx_df.csv")
rx_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)

# %%
rx_df.head()
# Out:
#           bnf_code                                           bnf_name  \
# 0  1502010J0AABDBD  Lidocaine 50mg/5ml (1%) solution for injection...
# 1  0403010B0AAAGAG                         Amitriptyline 10mg tablets
# 2  0704020N0AAABAB                            Tolterodine 2mg tablets
# 3  0403040W0AAALAL         Venlafaxine 225mg modified-release tablets
# 4  0104020L0AAADAD                             Loperamide 2mg tablets
#
#       items
# 0     81521
# 1  10519629
# 2    432135
# 3    218058
# 4    118266

# %% [markdown]
# We can now merge the two dataframes on BNF code

# %%
test_df = pd.merge(dmd_df, rx_df, left_on='bnf_code', right_on='bnf_code', how='right')

# %%
test_df.head()
# Out:
#   type                id                                                 nm  \
# 0  vmp    72171000001103  Tetanus immunoglobulin human 250unit solution ...
# 1  amp  4953011000001103  Tetanus immunoglobulin human 250unit solution ...
# 2  vmp   116081000001104                Imiquimod 3.75% cream 250mg sachets
# 3  vmp   116281000001109                    Lidocaine 5% medicated plasters
# 4  vmp   133141000001106                        Coal tar prepared 1% lotion
#
#          vtm                  vtm_nm         bnf_code  vmp_previous  \
# 0  777724003  Tetanus immunoglobulin  1405020A0AAABAB     333769007
# 1  777724003  Tetanus immunoglobulin  1405020A0AAABAB          <NA>
# 2  776315001               Imiquimod  1307000V0AAABAB     444988004
# 3  776528009               Lidocaine  1502010J0AAELEL     376491004
# 4  775333000                Coal tar  1305020C0AACXCX     332081009
#
#   vmp_previous_date                                        bnf_name   items
# 0        2022-01-12  Tetanus immunoglobulin human 250unit inj vials      28
# 1               NaT  Tetanus immunoglobulin human 250unit inj vials      28
# 2        2022-07-29             Imiquimod 3.75% cream 250mg sachets     943
# 3        2022-07-29                 Lidocaine 5% medicated plasters  106695
# 4        2022-07-29         Coal tar solution 5% cutaneous emulsion    6625

# %% [markdown]
# We can now check by seeing which items prescribed which don't have a corresponding `dm+d` code

# %%
test_df_no_dmd = test_df[test_df['id'].isnull()].sort_values(by='items', ascending=False) # filter only prescribing which has a null VMP or AMP
test_df_no_dmd.head()
# Out:
#        type    id   nm   vtm vtm_nm         bnf_code  vmp_previous  \
# 105653  NaN  <NA>  NaN  <NA>    NaN  190201000AABLBL          <NA>
# 105654  NaN  <NA>  NaN  <NA>    NaN  190201000AABPBP          <NA>
# 105657  NaN  <NA>  NaN  <NA>    NaN  190201000AABNBN          <NA>
# 105655  NaN  <NA>  NaN  <NA>    NaN  0913261J0BCAAAB          <NA>
# 105656  NaN  <NA>  NaN  <NA>    NaN  090402000BDFHA0          <NA>
#
#        vmp_previous_date                                        bnf_name  \
# 105653               NaT              Exception Handler Unspecified Item
# 105654               NaT  Exception Handler High Volume Unspecified Item
# 105657               NaT    Exception Handler Discount Not Deducted Item
# 105655               NaT                                  ProZero liquid
# 105656               NaT    Fresubin Energy tube feed liquid unflavoured
#
#          items
# 105653  314805
# 105654  184530
# 105657   20008
# 105655    4549
# 105656     205

# %% [markdown]
# We can see from the above there are very few items apart from "unspecified item", which by definition cannot have a BNF code.

# %% [markdown]
# The other part of the request was to link `VTM` codes.  We can also check which drugs do not link to a `VTM`.

# %%
test_vtm_no_dmd  = test_df[test_df['vtm'].isnull()].sort_values(by='items', ascending=False)

# %%
test_vtm_no_dmd.head(30)
# Out:
#        type                 id  \
# 62524   amp  17420611000001107
# 102741  amp  39094611000001105
# 864     amp  33558011000001102
# 861     amp  24554011000001105
# 865     amp  39034211000001101
# 860     amp  24377911000001104
# 859     amp  22673311000001107
# 858     amp  22393911000001107
# 857     amp  21790411000001105
# 856     amp  19282911000001103
# 855     amp  16446311000001101
# 854     amp  15503911000001106
# 853     vmp   3591211000001105
# 862     amp  28407111000001102
# 863     amp  28770311000001103
# 34478   amp    553611000001106
# 34404   amp    507711000001101
# 85929   amp  27967011000001107
# 11137   amp  32811711000001109
# 11136   amp  22755211000001108
# 11135   amp  15978911000001101
# 11127   vmp  34820511000001105
# 11128   amp   2918911000001106
# 11130   amp   3305411000001108
# 11131   amp   3306611000001101
# 11132   amp   3307111000001107
# 11138   amp  35570311000001105
# 11129   amp   3303311000001102
# 11134   amp  14165911000001106
# 11139   amp  37272611000001106
#
#                                                        nm   vtm vtm_nm  \
# 62524   Laxido Orange oral powder sachets sugar free (...  <NA>   None
# 102741  FreeStyle Libre 2 Sensor (Abbott Laboratories ...  <NA>   None
# 864     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 861     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 865     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 860     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 859     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 858     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 857     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 856     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 855     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 854     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 853     Macrogol compound oral powder sachets NPF suga...  <NA>   None
# 862     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 863     Macrogol compound oral powder sachets sugar fr...  <NA>   None
# 34478         Dermol 500 lotion (Dermal Laboratories Ltd)  <NA>   None
# 34404                     Otomize ear spray (Teva UK Ltd)  <NA>   None
# 85929           Epimax original cream (Aspire Pharma Ltd)  <NA>   None
# 11137   Vitamin B compound strong tablets (Genesis Pha...  <NA>   None
# 11136     Vitamin B compound strong tablets (Teva UK Ltd)  <NA>   None
# 11135   Vitamin B compound strong tablets (Zanza Speci...  <NA>   None
# 11127                   Vitamin B compound strong tablets  <NA>   None
# 11128   Vitamin B compound strong tablets (A A H Pharm...  <NA>   None
# 11130   Vitamin B compound strong tablets (The Boots C...  <NA>   None
# 11131   Vitamin B compound strong tablets (Kent Pharma...  <NA>   None
# 11132   Vitamin B compound strong tablets (Alliance He...  <NA>   None
# 11138   Vitamin B compound strong tablets (NorthStar H...  <NA>   None
# 11129   Vitamin B compound strong tablets (Accord-UK Ltd)  <NA>   None
# 11134   Vitamin B compound strong tablets (Healthcare ...  <NA>   None
# 11139   Vitamin B compound strong tablets (Mawdsley-Br...  <NA>   None
#
#                bnf_code  vmp_previous vmp_previous_date  \
# 62524   0106040M0BCACAA          <NA>               NaT
# 102741      21480000101          <NA>               NaT
# 864     0106040M0AAAAAA          <NA>               NaT
# 861     0106040M0AAAAAA          <NA>               NaT
# 865     0106040M0AAAAAA          <NA>               NaT
# 860     0106040M0AAAAAA          <NA>               NaT
# 859     0106040M0AAAAAA          <NA>               NaT
# 858     0106040M0AAAAAA          <NA>               NaT
# 857     0106040M0AAAAAA          <NA>               NaT
# 856     0106040M0AAAAAA          <NA>               NaT
# 855     0106040M0AAAAAA          <NA>               NaT
# 854     0106040M0AAAAAA          <NA>               NaT
# 853     0106040M0AAAAAA          <NA>               NaT
# 862     0106040M0AAAAAA          <NA>               NaT
# 863     0106040M0AAAAAA          <NA>               NaT
# 34478   130201000BBICBW          <NA>               NaT
# 34404   120101050BCAAAB          <NA>               NaT
# 85929       21220000241          <NA>               NaT
# 11137   0906027G0AAABAB          <NA>               NaT
# 11136   0906027G0AAABAB          <NA>               NaT
# 11135   0906027G0AAABAB          <NA>               NaT
# 11127   0906027G0AAABAB     329298009        2017-10-05
# 11128   0906027G0AAABAB          <NA>               NaT
# 11130   0906027G0AAABAB          <NA>               NaT
# 11131   0906027G0AAABAB          <NA>               NaT
# 11132   0906027G0AAABAB          <NA>               NaT
# 11138   0906027G0AAABAB          <NA>               NaT
# 11129   0906027G0AAABAB          <NA>               NaT
# 11134   0906027G0AAABAB          <NA>               NaT
# 11139   0906027G0AAABAB          <NA>               NaT
#
#                                                  bnf_name    items
# 62524        Laxido Orange oral powder sachets sugar free  2655605
# 102741                           FreeStyle Libre 2 Sensor  2150585
# 864     Macrogol compound oral powder sachets NPF suga...  1917581
# 861     Macrogol compound oral powder sachets NPF suga...  1917581
# 865     Macrogol compound oral powder sachets NPF suga...  1917581
# 860     Macrogol compound oral powder sachets NPF suga...  1917581
# 859     Macrogol compound oral powder sachets NPF suga...  1917581
# 858     Macrogol compound oral powder sachets NPF suga...  1917581
# 857     Macrogol compound oral powder sachets NPF suga...  1917581
# 856     Macrogol compound oral powder sachets NPF suga...  1917581
# 855     Macrogol compound oral powder sachets NPF suga...  1917581
# 854     Macrogol compound oral powder sachets NPF suga...  1917581
# 853     Macrogol compound oral powder sachets NPF suga...  1917581
# 862     Macrogol compound oral powder sachets NPF suga...  1917581
# 863     Macrogol compound oral powder sachets NPF suga...  1917581
# 34478                                   Dermol 500 lotion  1821608
# 34404                                   Otomize ear spray  1404453
# 85929                               Epimax original cream  1216588
# 11137                   Vitamin B compound strong tablets  1038779
# 11136                   Vitamin B compound strong tablets  1038779
# 11135                   Vitamin B compound strong tablets  1038779
# 11127                   Vitamin B compound strong tablets  1038779
# 11128                   Vitamin B compound strong tablets  1038779
# 11130                   Vitamin B compound strong tablets  1038779
# 11131                   Vitamin B compound strong tablets  1038779
# 11132                   Vitamin B compound strong tablets  1038779
# 11138                   Vitamin B compound strong tablets  1038779
# 11129                   Vitamin B compound strong tablets  1038779
# 11134                   Vitamin B compound strong tablets  1038779
# 11139                   Vitamin B compound strong tablets  1038779

# %%
group_vtm_no_dmd = test_vtm_no_dmd.groupby(['bnf_name'])[['items']].mean().sort_values(by='items', ascending=False)

# %%
group_vtm_no_dmd.head(30)
# Out:
#                                                      items
# bnf_name
# Laxido Orange oral powder sachets sugar free       2655605
# FreeStyle Libre 2 Sensor                           2150585
# Macrogol compound oral powder sachets NPF sugar... 1917581
# Dermol 500 lotion                                  1821608
# Otomize ear spray                                  1404453
# Epimax original cream                              1216588
# Vitamin B compound strong tablets                  1038779
# GlucoRx Nexus testing strips                       1020083
# Medi Derma-S barrier cream                          780871
# WaveSense JAZZ testing strips                       641966
# AeroChamber Plus                                    616982
# Aveeno cream                                        594467
# GlucoRx lancets 0.31mm/30gauge                      560800
# TEE2 testing strips                                 552581
# Sharpsafe disposal unit 1 litre                     538011
# Sharpsguard disposal unit 1 litre                   535991
# Hylo Night eye ointment preservative free           535073
# AeroChamber Plus with mask                          533485
# Evorel Sequi patches                                515739
# Xailin Night eye ointment preservative free         506890
# BD Viva hypodermic insulin needles for pre-fill...  499086
# Movicol Paediatric Plain oral powder 6.9g sachets   461458
# FastClix lancets 0.3mm/30gauge                      458615
# Proshield Plus skin protective                      456828
# Forceval capsules                                   428496
# Dermol cream                                        416425
# Fortisip Compact liquid (8 flavours)                402004
# Finetest Lite testing strips                        399933
# E45 cream                                           394031
# GlucoMen areo Sensor testing strips                 380857

# %% [markdown]
# The largest number of prescribing items with a `NULL` `VTM` are either a) where they are not drugs, but appliances or devices (such as Freestyle Libre), OR where the drug has more than 3 ingredients.  In this case (such as Laxido) no VTM is assigned to the formulation in the dm+d.  Therefore it appears that the table accurately reflects what the dm+d says.
